# %%
'''
   1. Number of times pregnant
   2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
   3. Diastolic blood pressure (mm Hg)
   4. Triceps skin fold thickness (mm)
   5. 2-Hour serum insulin (mu U/ml)
   6. Body mass index (weight in kg/(height in m)^2)
   7. Diabetes pedigree function
   8. Age (years)
   9. Class variable (0 or 1)
'''



from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json

#Loading data set from excel file through numpy
dataset = loadtxt('pima-indians-diabetes.csv', delimiter = ',')
x = dataset[:,0:8]
y = dataset[:,8]

# Designing of Model for training
model = Sequential() #Empty stack
model.add(Dense(24,input_dim = 8, activation = 'relu')) #12 Neurons, no. of inputs = 8
model.add(Dense(20, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))


model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(x, y, epochs = 1500, batch_size = 10) #  Training data set

# Overall Accuracy
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy * 100))

# Save the model in json file
model_json = model.to_json()
with open('model.json', 'w') as json_file :
    json_file.write(model_json)
model.save_weights('model.h5')
print('Saved model to disk')
# Out:
# Using TensorFlow backend.
# Epoch 1/1500
# 768/768 [==============================] - 0s 632us/step - loss: 3.5015 - accuracy: 0.6003
# Epoch 2/1500
# 768/768 [==============================] - 0s 129us/step - loss: 0.9871 - accuracy: 0.6393
# Epoch 3/1500
# 768/768 [==============================] - 0s 121us/step - loss: 0.8151 - accuracy: 0.6719
# Epoch 4/1500
# 768/768 [==============================] - 0s 130us/step - loss: 0.7768 - accuracy: 0.6732
# Epoch 5/1500
# 768/768 [==============================] - 0s 130us/step - loss: 0.7128 - accuracy: 0.6901
# Epoch 6/1500
# 768/768 [==============================] - 0s 129us/step - loss: 0.6637 - accuracy: 0.6875
# Epoch 7/1500
# 768/768 [==============================] - 0s 125us/step - loss: 0.6890 - accuracy: 0.6953
# Epoch 8/1500
# 768/768 [==============================] - 0s 116us/step - loss: 0.7328 - accuracy: 0.7018
# Epoch 9/1500
# 768/768 [==============================] - 0s 121us/step - loss: 0.7765 - accuracy: 0.6615
# ...
